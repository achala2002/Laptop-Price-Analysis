# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as px               #Whatever graphs we are plotting in seaborn plot it using plotly

# %%
df = pd.read_csv('/content/drive/MyDrive/Data analytics training/Project 1/laptop_price.csv',encoding = 'latin')
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# 1              Ultrabook    13.3                                    1440x900
# 2               Notebook    15.6                           Full HD 1920x1080
# 3              Ultrabook    15.4          IPS Panel Retina Display 2880x1800
# 4              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...                  ...     ...                                         ...
# 1298  2 in 1 Convertible    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  2 in 1 Convertible    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300            Notebook    14.0                                    1366x768
# 1301            Notebook    15.6                                    1366x768
# 1302            Notebook    15.6                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1299         Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1300             Intel HD Graphics  Windows 10   1.5kg       229.00
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00
#
# [1303 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %% [markdown]
# # Data Cleaning

# %%
#df.dropna
#df.drop
df.drop(columns = ['laptop_ID','Product'],inplace = True)

# %%
df.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 29

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (1274, 11)

# %%
df.sample(3)
# Out:
#     Company            TypeName  Inches             ScreenResolution  \
# 99       HP              Gaming    15.6  IPS Panel Full HD 1920x1080
# 881      HP  2 in 1 Convertible    15.6         Touchscreen 1366x768
# 817      HP             Netbook    11.6                     1366x768
#
#                                       Cpu   Ram                Memory  \
# 99            Intel Core i7 7700HQ 2.8GHz  12GB  128GB SSD +  1TB HDD
# 881            Intel Core i5 7200U 2.5GHz   4GB             500GB HDD
# 817  Intel Celeron Dual Core N3060 1.6GHz   4GB    16GB Flash Storage
#
#                          Gpu       OpSys  Weight  Price_euros
# 99   Nvidia GeForce GTX 1050  Windows 10  2.62kg       1249.0
# 881    Intel HD Graphics 620  Windows 10   2.3kg        684.8
# 817    Intel HD Graphics 400   Chrome OS  1.23kg        385.0

# %%
# 89.07 INR >> 1 euro
# 299.0*89.07 = INR

# %%
df['Price_euros'] = round(df['Price_euros']*89.07).astype('int')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg       119326
# 1        Intel HD Graphics 6000  macOS  1.34kg        80069
# 2         Intel HD Graphics 620  No OS  1.86kg        51215
# 3            AMD Radeon Pro 455  macOS  1.83kg       226011
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg       160647

# %%
df.rename(columns = {'Price_euros':'Price'},inplace = True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight   Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg  119326
# 1        Intel HD Graphics 6000  macOS  1.34kg   80069
# 2         Intel HD Graphics 620  No OS  1.86kg   51215
# 3            AMD Radeon Pro 455  macOS  1.83kg  226011
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg  160647

# %%
# RAM coverting from col to numeric Col
df['Ram'].value_counts()
# Out:
# Ram
# 8GB     613
# 4GB     366
# 16GB    198
# 6GB      35
# 12GB     25
# 32GB     17
# 2GB      16
# 24GB      3
# 64GB      1
# Name: count, dtype: int64

# %%
a = '4GB'
type(a)
# Out:
# str

# %%
a.replace('GB','')
# Out:
# '4'

# %%
(lambda a :a.replace("GB",""))('16GB')
# Out:
# '16'

# %%
df['Ram'] = df['Ram'].apply(lambda a :a.replace("GB","")).astype('int')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg  119326
# 1        Intel HD Graphics 6000  macOS  1.34kg   80069
# 2         Intel HD Graphics 620  No OS  1.86kg   51215
# 3            AMD Radeon Pro 455  macOS  1.83kg  226011
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg  160647

# %%
#EDA
df['Ram'].value_counts()
# Out:
# Ram
# 8     613
# 4     366
# 16    198
# 6      35
# 12     25
# 32     17
# 2      16
# 24      3
# 64      1
# Name: count, dtype: int64

# %%
sns.barplot(x = df['Ram'], y = df['Price'])
# Out:
# <Axes: xlabel='Ram', ylabel='Price'>

# %% [markdown]
# # Documentation

# %%
df['Weight'] = df['Weight'].apply(lambda a :a.replace("kg","")).astype(float)

# %%
df['Weight'].value_counts()
# Out:
# Weight
# 2.20    119
# 2.10     58
# 2.00     45
# 2.40     42
# 2.50     38
#        ...
# 4.50      1
# 1.14      1
# 3.80      1
# 3.25      1
# 2.34      1
# Name: count, Length: 171, dtype: int64

# %%
sns.displot(x = df['Weight'], kde = True)

# %%
sns.scatterplot(x = df['Weight'], y = df['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %% [markdown]
# # Doc

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1274 entries, 0 to 1273
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1274 non-null   object
#  1   TypeName          1274 non-null   object
#  2   Inches            1274 non-null   float64
#  3   ScreenResolution  1274 non-null   object
#  4   Cpu               1274 non-null   object
#  5   Ram               1274 non-null   int64
#  6   Memory            1274 non-null   object
#  7   Gpu               1274 non-null   object
#  8   OpSys             1274 non-null   object
#  9   Weight            1274 non-null   float64
#  10  Price             1274 non-null   int64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 119.4+ KB

# %%
df.sample()
# Out:
#     Company TypeName  Inches ScreenResolution  \
# 817      HP  Netbook    11.6         1366x768
#
#                                       Cpu  Ram              Memory  \
# 817  Intel Celeron Dual Core N3060 1.6GHz    4  16GB Flash Storage
#
#                        Gpu      OpSys  Weight  Price
# 817  Intel HD Graphics 400  Chrome OS    1.23  34292

# %%
df['Company'].value_counts()
# Out:
# Company
# Dell         291
# Lenovo       289
# HP           268
# Asus         151
# Acer         101
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
df.shape   #Before dropping companies
# Out:
# (1274, 11)

# %%
#Filtering for the companies which has repeated more than 10 times in the dataset
df = df[df.groupby('Company')["Company"].transform('count') > 10]

# %%
df['Company'].value_counts()
# Out:
# Company
# Dell       291
# Lenovo     289
# HP         268
# Asus       151
# Acer       101
# MSI         54
# Toshiba     48
# Apple       21
# Name: count, dtype: int64

# %%
df.shape      #After dropping companies
# Out:
# (1223, 11)

# %%
sns.barplot(x = df['Company'], y = df['Price'])
# Out:
# <Axes: xlabel='Company', ylabel='Price'>

# %% [markdown]
# # Document

# %%
df.sample()
# Out:
#     Company  TypeName  Inches ScreenResolution                        Cpu  \
# 231      HP  Notebook    15.6         1366x768  AMD E-Series 9000e 1.5GHz
#
#      Ram     Memory            Gpu       OpSys  Weight  Price
# 231    4  500GB HDD  AMD Radeon R2  Windows 10     2.1  29393

# %%
df['TypeName'].value_counts()
# Out:
# TypeName
# Notebook              687
# Gaming                200
# Ultrabook             171
# 2 in 1 Convertible    114
# Workstation            29
# Netbook                22
# Name: count, dtype: int64

# %%
df['TypeName'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x = df['TypeName'], y = df['Price'])
plt.xticks(rotation = 90)
plt.show()

# %%
df['Inches'].value_counts()
# Out:
# Inches
# 15.6    636
# 14.0    182
# 17.3    162
# 13.3    152
# 12.5     37
# 11.6     29
# 12.0      6
# 13.9      6
# 15.4      4
# 10.1      4
# 18.4      1
# 17.0      1
# 14.1      1
# 11.3      1
# 15.0      1
# Name: count, dtype: int64

# %%
df = df[df.groupby('Inches')["Inches"].transform('count') > 10]

# %%
df.shape    #after Filtering
# Out:
# (1198, 11)

# %%
df['Inches'].value_counts()
# Out:
# Inches
# 15.6    636
# 14.0    182
# 17.3    162
# 13.3    152
# 12.5     37
# 11.6     29
# Name: count, dtype: int64

# %%
#Inches vs Price
sns.scatterplot(x = df['Inches'], y = df['Price'] , palette = 'viridis')
plt.show()
# Out:
# <ipython-input-52-89f763ca4b2b>:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x = df['Inches'], y = df['Price'] , palette = 'viridis')

# %%
#Inches vs Price
sns.barplot(x = df['Inches'], y = df['Price'] , palette = 'viridis')
plt.show()
# Out:
# <ipython-input-53-0ee6d3890cf5>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = df['Inches'], y = df['Price'] , palette = 'viridis')

# %%
df.sample()
# Out:
#     Company   TypeName  Inches     ScreenResolution  \
# 385  Lenovo  Ultrabook    14.0  IPS Panel 2560x1440
#
#                             Cpu  Ram     Memory                    Gpu  \
# 385  Intel Core i7 7500U 2.7GHz    8  512GB SSD  Intel HD Graphics 620
#
#           OpSys  Weight   Price
# 385  Windows 10    1.13  203258

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                491
# 1366x768                                         256
# IPS Panel Full HD 1920x1080                      217
# Full HD / Touchscreen 1920x1080                   44
# IPS Panel Full HD / Touchscreen 1920x1080         43
# 1600x900                                          22
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160      8
# 4K Ultra HD / Touchscreen 3840x2160                8
# 4K Ultra HD 3840x2160                              7
# IPS Panel 1366x768                                 7
# Touchscreen 2560x1440                              7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Touchscreen 2560x1440                    5
# 1440x900                                           4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ / Touchscreen 3200x1800         4
# 2560x1440                                          3
# IPS Panel Quad HD+ 2560x1440                       3
# IPS Panel Touchscreen 1366x768                     3
# Quad HD+ 3200x1800                                 3
# IPS Panel Quad HD+ 3200x1800                       2
# 1920x1080                                          2
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# Touchscreen / Quad HD+ 3200x1800                   1
# IPS Panel Full HD 1366x768                         1
# IPS Panel Full HD 2560x1440                        1
# Touchscreen / Full HD 1920x1080                    1
# Name: count, dtype: int64

# %%
a = 'IPS Panel Full HD / Touchscreen 1920x1080'
#X_res = 1920 , Y_res = 1080

# %%
a.split()[-1]
# Out:
# '1920x1080'

# %%
a.split()[-1].split('x')
# Out:
# ['1920', '1080']

# %%
a.split()[-1].split('x')[0]   #X_res
# Out:
# '1920'

# %%
a.split()[-1].split('x')[1]   #Y_res
# Out:
# '1080'

# %%
(lambda x : x.split()[-1].split('x')[0])('1920x1080')   #X_res
# Out:
# '1920'

# %%
(lambda x : x.split()[-1].split('x')[1])('1920x1080')   #Y_res
# Out:
# '1080'

# %%
df['X_res'] = df['ScreenResolution'].apply((lambda x : x.split()[-1].split('x')[0])).astype('int')

# %%
df['Y_res'] = df['ScreenResolution'].apply((lambda x : x.split()[-1].split('x')[1])).astype('int')

# %%
def pow(a,b):
  return a**b

# %%
x = lambda a : a**2

# %%
x(2)
# Out:
# 4

# %%
pow(2,3)
# Out:
# 8

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 5    Acer   Notebook    15.6                            1366x768
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
# 5     AMD A9-Series 9420 3GHz    4            500GB HDD
#
#                             Gpu       OpSys  Weight   Price  X_res  Y_res
# 0  Intel Iris Plus Graphics 640       macOS    1.37  119326   2560   1600
# 1        Intel HD Graphics 6000       macOS    1.34   80069   1440    900
# 2         Intel HD Graphics 620       No OS    1.86   51215   1920   1080
# 4  Intel Iris Plus Graphics 650       macOS    1.37  160647   2560   1600
# 5                 AMD Radeon R5  Windows 10    2.10   35628   1366    768

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Pixels per inch (PPI) refers to the number of pixels contained within each inch of a digital image. It also refers to the set number of pixels a screen can display. Generally speaking, the higher the PPI, the better the image quality.

# %%
#Add a column for ppi
#X_res
#Y_res
#Inches

# %%
df['ppi'] = round(((df['X_res']**2)+(df['Y_res']**2))**0.5/df['Inches'])

# %%
df.sample()
# Out:
#     Company            TypeName  Inches                 ScreenResolution  \
# 219    Dell  2 in 1 Convertible    13.3  Full HD / Touchscreen 1920x1080
#
#                             Cpu  Ram     Memory                     Gpu  \
# 219  Intel Core i7 8550U 1.8GHz   16  512GB SSD  Intel UHD Graphics 620
#
#           OpSys  Weight   Price  X_res  Y_res    ppi
# 219  Windows 10    1.62  113921   1920   1080  166.0

# %%
#ppi vs price analysis
df['ppi'].value_counts()
# Out:
# ppi
# 141.0    419
# 100.0    194
# 127.0    131
# 157.0    122
# 166.0    100
# 112.0     42
# 135.0     28
# 276.0     25
# 176.0     25
# 282.0     23
# 106.0     22
# 210.0     18
# 125.0      9
# 118.0      8
# 331.0      7
# 227.0      6
# 255.0      5
# 128.0      4
# 352.0      2
# 170.0      2
# 91.0       2
# 221.0      2
# 190.0      1
# 235.0      1
# Name: count, dtype: int64

# %%
sns.regplot(x = df['ppi'], y = df['Price'])
# Out:
# <Axes: xlabel='ppi', ylabel='Price'>

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                491
# 1366x768                                         256
# IPS Panel Full HD 1920x1080                      217
# Full HD / Touchscreen 1920x1080                   44
# IPS Panel Full HD / Touchscreen 1920x1080         43
# 1600x900                                          22
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160      8
# 4K Ultra HD / Touchscreen 3840x2160                8
# 4K Ultra HD 3840x2160                              7
# IPS Panel 1366x768                                 7
# Touchscreen 2560x1440                              7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Touchscreen 2560x1440                    5
# 1440x900                                           4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ / Touchscreen 3200x1800         4
# 2560x1440                                          3
# IPS Panel Quad HD+ 2560x1440                       3
# IPS Panel Touchscreen 1366x768                     3
# Quad HD+ 3200x1800                                 3
# IPS Panel Quad HD+ 3200x1800                       2
# 1920x1080                                          2
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# Touchscreen / Quad HD+ 3200x1800                   1
# IPS Panel Full HD 1366x768                         1
# IPS Panel Full HD 2560x1440                        1
# Touchscreen / Full HD 1920x1080                    1
# Name: count, dtype: int64

# %%
a ='IPS Panel Full HD / Touchscreen 1920x1080'
#if there is IPS in this str then return 1 else 0
(lambda a: 1 if 'IPS' in a else 0)('IPS Panel Full HD / Touchscreen 1920x1080')
# Out:
# 1

# %%
df['IPS'] = df['ScreenResolution'].apply(lambda a: 1 if 'IPS' in a else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 5    Acer   Notebook    15.6                            1366x768
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
# 5     AMD A9-Series 9420 3GHz    4            500GB HDD
#
#                             Gpu       OpSys  Weight   Price  X_res  Y_res  \
# 0  Intel Iris Plus Graphics 640       macOS    1.37  119326   2560   1600
# 1        Intel HD Graphics 6000       macOS    1.34   80069   1440    900
# 2         Intel HD Graphics 620       No OS    1.86   51215   1920   1080
# 4  Intel Iris Plus Graphics 650       macOS    1.37  160647   2560   1600
# 5                 AMD Radeon R5  Windows 10    2.10   35628   1366    768
#
#      ppi  IPS
# 0  227.0    1
# 1  128.0    0
# 2  141.0    0
# 4  227.0    1
# 5  100.0    0

# %%
df['TouchScreen'] = df['ScreenResolution'].apply(lambda a: 1 if 'Touchscreen' in a else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 5    Acer   Notebook    15.6                            1366x768
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
# 5     AMD A9-Series 9420 3GHz    4            500GB HDD
#
#                             Gpu       OpSys  Weight   Price  X_res  Y_res  \
# 0  Intel Iris Plus Graphics 640       macOS    1.37  119326   2560   1600
# 1        Intel HD Graphics 6000       macOS    1.34   80069   1440    900
# 2         Intel HD Graphics 620       No OS    1.86   51215   1920   1080
# 4  Intel Iris Plus Graphics 650       macOS    1.37  160647   2560   1600
# 5                 AMD Radeon R5  Windows 10    2.10   35628   1366    768
#
#      ppi  IPS  TouchScreen
# 0  227.0    1            0
# 1  128.0    0            0
# 2  141.0    0            0
# 4  227.0    1            0
# 5  100.0    0            0

# %%
df['TouchScreen'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='TouchScreen'>

# %%
df['ppi'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='ppi'>

# %%
df.drop(columns = ['ScreenResolution','Inches','X_res','Y_res'],inplace = True)

# %%
df.shape
# Out:
# (1198, 12)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
# 5    Acer   Notebook     AMD A9-Series 9420 3GHz    4            500GB HDD
#
#                             Gpu       OpSys  Weight   Price    ppi  IPS  \
# 0  Intel Iris Plus Graphics 640       macOS    1.37  119326  227.0    1
# 1        Intel HD Graphics 6000       macOS    1.34   80069  128.0    0
# 2         Intel HD Graphics 620       No OS    1.86   51215  141.0    0
# 4  Intel Iris Plus Graphics 650       macOS    1.37  160647  227.0    1
# 5                 AMD Radeon R5  Windows 10    2.10   35628  100.0    0
#
#    TouchScreen
# 0            0
# 1            0
# 2            0
# 4            0
# 5            0

# %%
df['Cpu'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Cpu'>

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz     183
# Intel Core i7 7700HQ 2.8GHz    142
# Intel Core i7 7500U 2.7GHz     122
# Intel Core i5 8250U 1.6GHz      70
# Intel Core i7 8550U 1.8GHz      68
#                               ...
# AMD E-Series E2-9000 2.2GHz      1
# Intel Core i5 2.0GHz             1
# Intel Core M M3-6Y30 0.9GHz      1
# AMD A9-Series 9420 2.9GHz        1
# AMD A9-Series 9410 2.9GHz        1
# Name: count, Length: 100, dtype: int64

# %%
a = 'Intel Core i5 7200U 2.5GHz'

# %%
a.split()        #to convert str into list
# Out:
# ['Intel', 'Core', 'i5', '7200U', '2.5GHz']

# %%
a.split()[0:3]
# Out:
# ['Intel', 'Core', 'i5']

# %%
' '.join(a.split()[0:3])
# Out:
# 'Intel Core i5'

# %%
(lambda a: ' '.join(a.split()[0:3]))('AMD E-Series E2-9000 2.2GHz')
# Out:
# 'AMD E-Series E2-9000'

# %%
df['Cpu'] = df['Cpu'].apply(lambda a: ' '.join(a.split()[0:3]))

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i7               483
# Intel Core i5               409
# Intel Core i3               133
# Intel Celeron Dual           64
# Intel Pentium Quad           27
# AMD A9-Series 9420           11
# Intel Core M                 10
# AMD A6-Series 9220            8
# AMD A12-Series 9720P          7
# Intel Celeron Quad            5
# AMD A8-Series 7410            4
# Intel Pentium Dual            3
# AMD Ryzen 1700                3
# AMD A9-Series A9-9420         2
# Intel Xeon E3-1535M           2
# AMD A10-Series 9600P          2
# AMD E-Series 7110             2
# AMD A10-Series 9620P          2
# AMD A6-Series A6-9220         2
# AMD A10-Series A10-9620P      2
# Intel Xeon E3-1505M           2
# AMD E-Series E2-9000e         2
# AMD E-Series 9000e            1
# AMD Ryzen 1600                1
# AMD E-Series 6110             1
# AMD FX 9830P                  1
# AMD E-Series E2-6110          1
# AMD E-Series E2-9000          1
# AMD A6-Series 7310            1
# Intel Atom x5-Z8350           1
# AMD A12-Series 9700P          1
# AMD A4-Series 7210            1
# AMD FX 8800P                  1
# AMD E-Series 9000             1
# AMD A9-Series 9410            1
# Name: count, dtype: int64

# %%
#Will filter the AMD cpu w.r.t the Series
#AMD A9-Series 9420  >> AMD A-Series
#AMD E-Series 9000   >> AMD E-Series
#AMD FX 8800P        >> AMD F-Series

# %%
def fetch_pro(text):
  if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
    return text
  elif text.split()[0] == 'Intel':
    return 'Other Intel Processor'
  else:
    if text[4] == 'E':
      return 'AMD E-Series'
    elif text[4] == 'A':
      return 'AMD A-Series'
    elif text[4] == 'F':
      return 'AMD F-Series'
    else:
      return 'AMD Ryzen Series'

# %%
fetch_pro('Intel Core i7')
# Out:
# 'Intel Core i7'

# %%
df['Cpu'] = df['Cpu'].apply(fetch_pro)

# %%
df['Cpu'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Cpu'>

# %%
sns.barplot(x = df['Cpu'], y = df['Price'])
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # doc

# %%
a = 'Intel Celeron Dual'
a.split()[0]
# Out:
# 'Intel'

# %%
b = 'AMD E-Series E2-6110'
b[4]
# Out:
# 'E'

# %%
df.sample(3)
# Out:
#      Company  TypeName            Cpu  Ram     Memory                    Gpu  \
# 512     Dell  Notebook  Intel Core i5    8    1TB HDD  Intel HD Graphics 620
# 1246    Dell  Notebook  Intel Core i5    4  500GB HDD  Intel HD Graphics 620
# 229       HP  Notebook  Intel Core i7    8    1TB HDD    AMD FirePro W4190M
#
#            OpSys  Weight   Price    ppi  IPS  TouchScreen
# 512   Windows 10    2.18   74463  141.0    0            0
# 1246  Windows 10    1.60   77936  112.0    0            0
# 229   Windows 10    1.90  113030  141.0    0            0

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620       262
# Intel HD Graphics 520       179
# Nvidia GeForce GTX 1050      65
# Intel UHD Graphics 620       64
# Nvidia GeForce GTX 1060      45
#                            ...
# AMD Radeon R5 520             1
# AMD Radeon R7                 1
# Intel HD Graphics 540         1
# Nvidia GeForce GTX 1070M      1
# Nvidia GeForce 960M           1
# Name: count, Length: 102, dtype: int64

# %%
df['Gpu'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Gpu'>

# %%
a = 'Intel HD Graphics 620'

# %%
a.split()
# Out:
# ['Intel', 'HD', 'Graphics', '620']

# %%
a.split()[0:2]
# Out:
# ['Intel', 'HD']

# %%
" ".join(a.split()[0:2])
# Out:
# 'Intel HD'

# %%
(lambda a:" ".join(a.split()[0:2]))('AMD Radeon R5 520')
# Out:
# 'AMD Radeon'

# %%
df['Gpu'] = df['Gpu'].apply(lambda a:" ".join(a.split()[0:2]))

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD          570
# Nvidia GeForce    353
# AMD Radeon        162
# Intel UHD          64
# Nvidia Quadro      31
# Intel Iris         10
# AMD FirePro         5
# AMD R4              1
# AMD R17M-M1-70      1
# Intel Graphics      1
# Name: count, dtype: int64

# %%
sns.barplot(x = df['Gpu'], y = df['Price'])
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Document

# %%
df.sample()
# Out:
#     Company  TypeName            Cpu  Ram     Memory       Gpu       OpSys  \
# 868    Acer  Notebook  Intel Core i5    8  256GB SSD  Intel HD  Windows 10
#
#      Weight  Price    ppi  IPS  TouchScreen
# 868    1.56  80341  157.0    1            0

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      997
# No OS            63
# Linux            58
# Windows 7        45
# Chrome OS        22
# macOS             8
# Mac OS X          3
# Windows 10 S      2
# Name: count, dtype: int64

# %%
#Wherever we have Windows 10 or Window 10 S >>> Windows 10
#Windows 7 >> Windows 7
#if we have Mac OS X	or macOS >>  mac OS
#No OS >> No OS
#Linux >> Linux
#Chrome OS >>> Chrome OS

# %%
def os(text):
  if text == 'Windows 10' or text == 'Windows 10 S':
    return 'Windows 10'
  elif text == 'Windows 7':
    return 'Windows 7'
  elif text == 'macOS'  or text == 'Mac OS X':
    return 'mac OS'
  elif text == 'No OS':
    return 'No OS'
  elif text == 'Linux':
    return "Linux"
  else:
    return "Chrome OS"

# %%
os('Windows 10 S')
# Out:
# 'Windows 10'

# %%
df['OpSys'] = df['OpSys'].apply(os)

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10    999
# No OS          63
# Linux          58
# Windows 7      45
# Chrome OS      22
# mac OS         11
# Name: count, dtype: int64

# %%
sns.barplot(x = df['OpSys'], y = df['Price'])
plt.xticks(rotation = 90)
plt.show()

# %%
df[df['OpSys'] == 'Windows 10']['Price'].describe()
# Out:
# count       999.000000
# mean     104300.167167
# std       58624.172793
# min       17093.000000
# 25%       60122.000000
# 50%       92544.000000
# 75%      133560.500000
# max      436354.000000
# Name: Price, dtype: float64

# %%
sns.displot(data = df, x ='OpSys', y = 'Price')

# %%
df.sample(3)
# Out:
#      Company   TypeName            Cpu  Ram     Memory       Gpu       OpSys  \
# 893   Lenovo  Ultrabook  Intel Core i5    8  256GB SSD  Intel HD  Windows 10
# 1009      HP   Notebook  Intel Core i3    4  500GB HDD  Intel HD  Windows 10
# 1074  Lenovo  Ultrabook  Intel Core i7    8  256GB SSD  Intel HD  Windows 10
#
#       Weight   Price    ppi  IPS  TouchScreen
# 893     1.32  160237  157.0    1            0
# 1009    1.64   60924  112.0    0            0
# 1074    1.30  152621  176.0    1            1

# %%
#Flash Storage
#SDD
#HDD
#Hybrid
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        387
# 1TB HDD                          213
# 500GB HDD                        122
# 512GB SSD                         99
# 128GB SSD +  1TB HDD              93
# 256GB SSD +  1TB HDD              73
# 128GB SSD                         71
# 32GB Flash Storage                28
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              13
# 1TB SSD                           12
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       7
# 64GB Flash Storage                 6
# 16GB Flash Storage                 6
# 256GB Flash Storage                5
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 32GB SSD                           2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 1TB SSD +  1TB HDD                 2
# 64GB SSD                           1
# 240GB SSD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 1.0TB HDD                          1
# 508GB Hybrid                       1
# 8GB SSD                            1
# 64GB Flash Storage +  1TB HDD      1
# 128GB HDD                          1
# 1TB HDD +  1TB HDD                 1
# 512GB SSD +  256GB SSD             1
# 512GB SSD +  512GB SSD             1
# 256GB SSD +  1.0TB Hybrid          1
# Name: count, dtype: int64

# %%
df['Memory'].str.split('+',n=1,expand=True).sample(5)
# Out:
#               0     1
# 986     1TB HDD  None
# 957   256GB SSD  None
# 397   256GB SSD  None
# 795   256GB SSD  None
# 1054    1TB SSD  None

# %%
# SSD
# HDD
# Hybrid
# Flash Storage
new=df['Memory'].str.split('+',n=1,expand=True)
df['first']=new[0]
df['first']=df['first'].str.strip()
df['second']=new[1]

df['Layer1HDD']=df['first'].apply(lambda x:1 if "HDD" in x else 0) #
df['Layer1SSD']=df['first'].apply(lambda x:1 if "SSD" in x else 0)
df['Layer1Hybrid']=df['first'].apply(lambda x:1 if "Hybrid" in x else 0)
df['Layer1Flash_Storage']=df['first'].apply(lambda x:1 if "Flash Storage" in x else 0)

df['first']=df['first'].str.replace(r'\D','',regex=True)

df['second'].fillna("0",inplace=True)

df['second']=df['second'].str.strip()
df['Layer2HDD']=df['second'].apply(lambda x:1 if "HDD" in x else 0)
df['Layer2SSD']=df['second'].apply(lambda x:1 if "SSD" in x else 0)
df['Layer2Hybrid']=df['second'].apply(lambda x:1 if "Hybrid" in x else 0)
df['Layer2Flash_Storage']=df['second'].apply(lambda x:1 if "Flash Storage" in x else 0)

df['second']=df['second'].str.replace(r'\D','',regex=True)

df['first']=df['first'].astype('int')
df['second']=df['second'].astype('int')

df['HDD']=df['first']*df['Layer1HDD']+df['second']*df['Layer2HDD']

df['SSD']=df['first']*df['Layer1SSD']+df['second']*df['Layer2SSD']

df['Hybrid']=df['first']*df['Layer1Hybrid']+df['second']*df['Layer2Hybrid']

df['Flash_Storage']=df['first']*df['Layer1Flash_Storage']+df['second']*df['Layer2Flash_Storage']

df.drop(columns=['first','second','Layer1HDD','Layer1SSD','Layer1Hybrid','Layer1Flash_Storage',
                 'Layer2HDD','Layer2SSD','Layer2Hybrid','Layer2Flash_Storage'],inplace=True)
# Out:
# <ipython-input-162-ec09e9c49f89>:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['second'].fillna("0",inplace=True)

# %%
df.sample(5)
# Out:
#     Company   TypeName            Cpu  Ram     Memory             Gpu  \
# 439    Asus   Notebook  Intel Core i5    4  256GB SSD        Intel HD
# 687    Dell   Notebook  Intel Core i3    4    1TB HDD      AMD Radeon
# 411  Lenovo  Ultrabook  Intel Core i7    8  512GB SSD  Nvidia GeForce
# 116      HP   Notebook  Intel Core i7    8  512GB SSD       Intel UHD
# 344    Dell  Ultrabook  Intel Core i7    8  256GB SSD       Intel UHD
#
#           OpSys  Weight   Price    ppi  IPS  TouchScreen  HDD  SSD  Hybrid  \
# 439       Linux    2.00   49790  141.0    0            0    0  256       0
# 687  Windows 10    2.20   48603  100.0    0            0    1    0       0
# 411  Windows 10    1.70  173063  210.0    1            0    0  512       0
# 116  Windows 10    1.63   96552  157.0    0            0    0  512       0
# 344  Windows 10    1.20  140642  166.0    0            0    0  256       0
#
#      Flash_Storage
# 439              0
# 687              0
# 411              0
# 116              0
# 344              0

# %%
df.to_csv('Cleaned.csv')

# %%
df.sample(5)
# Out:
#      Company            TypeName            Cpu  Ram                  Memory  \
# 974     Asus              Gaming  Intel Core i7   16    256GB SSD +  1TB HDD
# 243     Dell              Gaming  Intel Core i5    8               256GB SSD
# 432   Lenovo            Notebook  Intel Core i3    4               128GB SSD
# 1159      HP  2 in 1 Convertible  Intel Core i7    8               512GB SSD
# 1045      HP            Notebook  Intel Core i5    8  256GB SSD +  500GB HDD
#
#                  Gpu       OpSys  Weight   Price    ppi  IPS  TouchScreen  \
# 974   Nvidia GeForce  Windows 10    2.73  182585  127.0    0            0
# 243   Nvidia GeForce  Windows 10    2.56   78293  141.0    0            0
# 432         Intel HD  Windows 10    1.70   53353  157.0    1            0
# 1159        Intel HD  Windows 10    1.48  181792  221.0    0            1
# 1045        Intel HD  Windows 10    1.84  187344  141.0    0            0
#
#       HDD  SSD  Hybrid  Flash_Storage
# 974     1  256       0              0
# 243     0  256       0              0
# 432     0  128       0              0
# 1159    0  512       0              0
# 1045  500  256       0              0

# %% [markdown]
# # Lambda Theory with practical explanation 15 mins

# %%
add = lambda x,y : x + y

# %%
add(2,4)
# Out:
# 6
